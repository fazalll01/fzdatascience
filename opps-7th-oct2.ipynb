# %%
class BankAccount:
    def __init__(self, account_number, account_holder_name, balance=0):
        self.account_number = account_number
        self.account_holder_name = account_holder_name
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited ${amount}. Current balance: ${self.balance}")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient balance.")
        else:
            self.balance -= amount
            print(f"Withdrawn ${amount}. Current balance: ${self.balance}")

# %%
class Employee:
    def __init__(self, employee_id, name, salary):
        self.employee_id = employee_id
        self.name = name
        self.salary = salary

    def calculate_yearly_bonus(self, bonus_percentage):
        bonus = self.salary * (bonus_percentage / 100)
        return bonus

    def display_employee_details(self):
        print(f"Employee ID: {self.employee_id}")
        print(f"Name: {self.name}")
        print(f"Salary: ${self.salary}")

# %%
class VehicleRental:
    def __init__(self):
        self.available_vehicles = []

    def rent_vehicle(self, vehicle):
        if vehicle in self.available_vehicles:
            self.available_vehicles.remove(vehicle)
            print(f"{vehicle} has been rented.")
        else:
            print(f"{vehicle} is not available for rent.")

    def return_vehicle(self, vehicle):
        self.available_vehicles.append(vehicle)
        print(f"{vehicle} has been returned.")

    def display_available_vehicles(self):
        print("Available vehicles:")
        for vehicle in self.available_vehicles:
            print(vehicle)

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

class Library:
    def __init__(self):
        self.books = []

    def add_book(self, book):
        self.books.append(book)
        print(f"{book.title} by {book.author} has been added to the library.")

    def borrow_book(self, book):
        if book in self.books:
            self.books.remove(book)
            print(f"{book.title} by {book.author} has been borrowed.")
        else:
            print(f"{book.title} by {book.author} is not available in the library.")

    def display_available_books(self):
        print("Available books:")
        for book in self.books:
            print(f"{book.title} by {book.author}")

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

class Inventory:
    def __init__(self):
        self.products = []

    def add_product(self, product):
        self.products.append(product)
        print(f"{product.name} has been added to the inventory.")

    def update_product_quantity(self, product, new_quantity):
        for p in self.products:
            if p.name == product.name:
                p.quantity = new_quantity
                print(f"{product.name} quantity updated to {new_quantity}.")
                break
        else:
            print(f"{product.name} is not in the inventory.")

    def display_available_products(self):
        print("Available products:")
        for product in self.products:
            print(f"{product.name} - Price: ${product.price}, Quantity: {product.quantity}")

# %%
class Shape:
    def __init__(self, length, width, height=None):
        self.length = length
        self.width = width
        self.height = height

    def calculate_area(self):
        if self.height:
            return self.length * self.width * self.height
        else:
            return self.length * self.width

    def calculate_perimeter(self):
        if self.height:
            return 2 * (self.length + self.width + self.height)
        else:
            return 2 * (self.length + self.width)

# %%
class Student:
    def __init__(self, student_id, name, grades):
        self.student_id = student_id
        self.name = name
        self.grades = grades

    def calculate_average_grade(self):
        return sum(self.grades) / len(self.grades)

    def display_student_details(self):
        print(f"Student ID: {self.student_id}")
        print(f"Name: {self.name}")
        print(f"Grades: {self.grades}")
        print(f"Average Grade: {self.calculate_average_grade()}")

# %%
class Email:
    def __init__(self, sender, recipient, subject, body):
        self.sender = sender
        self.recipient = recipient
        self.subject = subject
        self.body = body

    def send_email(self):
        print(f"Sending email from {self.sender} to {self.recipient}")
        print(f"Subject: {self.subject}")
        print(f"Body: {self.body}")

    def display_email_details(self):
        print(f"From: {self.sender}")
        print(f"To: {self.recipient}")
        print(f"Subject: {self.subject}")
        print(f"Body: {self.body}")

# %%
class SocialMediaProfile:
    def __init__(self, username):
        self.username = username
        self.posts = []

    def add_post(self, post):
        self.posts.append(post)
        print(f"{post} has been posted.")

    def display_posts(self):
        print(f"Posts by {self.username}:")
        for post in self.posts:
            print(post)

    def search_posts(self, keyword):
        matching_posts = [post for post in self.posts if keyword.lower() in post.lower()]
        print(f"Posts containing '{keyword}':")
        for post in matching_posts:
            print(post)

# %%
class ToDoList:
    def __init__(self):
        self.tasks = []

    def add_task(self, task, due_date):
        self.tasks.append((task, due_date))
        print(f"{task} has been added to the ToDo list. Due date: {due_date}")

    def mark_task_completed(self, task):
        for t in self.tasks:
            if t[0] == task:
                self.tasks.remove(t)
                print(f"{task} has been marked as completed.")
                break
        else:
            print(f"{task} is not in the ToDo list.")

    def display_pending_tasks(self):
        print("Pending tasks:")
        for task, due_date in self.tasks:
            print(f"{task} - Due date: {due_date}")

# %%
# Constructor Assignment

# 1. What is a constructor in Python? Explain its purpose and usage.
"""
A constructor in Python is a special type of method that is automatically called when an object of a class is created. Its purpose is to initialize the attributes of the object with appropriate values. Constructors help in creating objects with desired initial states and setting up necessary configurations or resources required by the object.
"""

# 2. Differentiate between a parameterless constructor and a parameterized constructor in Python.
"""
In Python, there is no explicit syntax for defining constructors like in some other programming languages. Instead, the __init__ method serves as the constructor.

A parameterless constructor (or default constructor) is an __init__ method that takes no arguments except for the self parameter. It is used to create objects with default or no initial values for attributes.

A parameterized constructor (or constructor with parameters) is an __init__ method that takes additional arguments besides the self parameter. These arguments are used to initialize the object's attributes with user-provided values.
"""

# 3. How do you define a constructor in a Python class? Provide an example.
class MyClass:
   def __init__(self, arg1, arg2):
       self.attr1 = arg1
       self.attr2 = arg2

# This defines a constructor __init__ with two parameters arg1 and arg2, which are used to initialize the attributes attr1 and attr2 of the object.

# 4. Explain the __init__ method in Python and its role in constructors.
"""
The __init__ method is a special method in Python classes that serves as the constructor. It is automatically called when an object of the class is created. Its primary role is to initialize the attributes of the object with appropriate values.

Within the __init__ method, you can perform any necessary setup or configuration for the object, such as allocating resources, setting default values, or performing validation checks on the provided arguments.

The first parameter of the __init__ method is always self, which refers to the instance of the class being created. Subsequent parameters can be used to accept values that will be used to initialize the object's attributes.
"""

# 5. In a class named `Person`, create a constructor that initializes the `name` and `age` attributes. Provide an
# example of creating an object of this class.
class Person:
   def __init__(self, name, age):
       self.name = name
       self.age = age

# Creating an object of the Person class
person1 = Person("Alice", 25)

# 6. How can you call a constructor explicitly in Python? Give an example.
"""
In Python, you cannot directly call a constructor explicitly. Instead, the __init__ method is automatically invoked when you create an instance of a class using the class name followed by parentheses, optionally passing the required arguments.
"""

# Example
class Car:
   def __init__(self, make, model):
       self.make = make
       self.model = model

# Creating an object of the Car class implicitly calls the constructor
car1 = Car("Toyota", "Camry")

# 7. What is the significance of the `self` parameter in Python constructors? Explain with an example.
"""
The self parameter in Python constructors (and in all instance methods) refers to the instance of the class itself. It is used to access and modify the attributes and methods of the object being created or operated upon.

When you create an object and call a method on it, Python automatically passes the instance of the object as the first argument to the method, which is conventionally named self. This allows the method to access and manipulate the attributes and other methods of that specific object.
"""

# Example
class Circle:
   def __init__(self, radius):
       self.radius = radius

   def area(self):
       return 3.14 * (self.radius ** 2)

# In this example, self.radius inside the __init__ method refers to the radius attribute of the specific Circle object being created. Inside the area method, self.radius refers to the radius attribute of the same Circle object on which the area method is called.

# 8. Discuss the concept of default constructors in Python. When are they used?
"""
In Python, a default constructor (or parameterless constructor) refers to an __init__ method that takes no arguments except for the self parameter. It is used to create objects with default or no initial values for attributes.

Default constructors are often used when:

1. You want to create objects without any initial values or with default values set within the class.
2. You need to perform some common initialization or setup tasks for all objects of the class, regardless of the values provided.
3. You want to provide a simple way to create objects without requiring any arguments.

If you don't define an __init__ method in your class, Python automatically provides a default constructor that takes no arguments. However, it is generally considered good practice to define your own __init__ method, even if it is a default constructor, to make your code more explicit and easier to understand.
"""

# 9. Create a Python class called `Rectangle` with a constructor that initializes the `width` and `height`
# attributes. Provide a method to calculate the area of the rectangle.
class Rectangle:
   def __init__(self, width, height):
       self.width = width
       self.height = height

   def area(self):
       return self.width * self.height

# 10. How can you have multiple constructors in a Python class? Explain with an example.
"""
In Python, there is no direct way to define multiple constructors like in some other programming languages. However, you can achieve similar functionality by using method overloading or by providing default values for parameters in the __init__ method.

One way to have multiple constructors is by using default parameter values in the __init__ method. This allows you to create objects with different combinations of arguments, effectively simulating multiple constructors.
"""

# Example
class Rectangle:
   def __init__(self, width=0, height=0, color="red"):
       self.width = width
       self.height = height
       self.color = color

   def area(self):
       return self.width * self.height

# Creating objects with different combinations of arguments
rect1 = Rectangle(5, 10)  # width=5, height=10, color='red' (default)
rect2 = Rectangle(3, 4, "blue")  # width=3, height=4, color='blue'
rect3 = Rectangle(color="green")  # width=0, height=0, color='green'

# 11. What is method overloading, and how is it related to constructors in Python?
"""
Method overloading refers to the ability to define multiple methods with the same name but different signatures (different number or types of parameters) within a class. In Python, this is not directly supported for methods, including constructors.

While Python does not have true method overloading, you can achieve similar functionality by using default parameter values, variable-length argument lists (*args and **kwargs), or by providing different method names with different signatures.

In the context of constructors, you can simulate method overloading by using default parameter values in the __init__ method, as shown in the previous example. This allows you to create objects with different combinations of arguments, effectively simulating multiple constructors.
"""

# 12. Explain the use of the `super()` function in Python constructors. Provide an example.
"""
The super() function in Python is used to call a method in a parent class from a derived (child) class. It is particularly useful when dealing with inheritance and constructors.

In the context of constructors, super().__init__() is used to call the constructor (__init__ method) of the parent class from the child class constructor. This is necessary when you want to initialize attributes defined in the parent class, as well as any additional attributes defined in the child class.
"""

# Example
class Vehicle:
   def __init__(self, make, model):
       self.make = make
       self.model = model

class Car(Vehicle):
   def __init__(self, make, model, year):
       super().__init__(make, model)  # Call the Vehicle constructor
       self.year = year

# In this example, the Car class inherits from the Vehicle class. When creating a Car object, the Car constructor calls super().__init__(make, model) to initialize the make and model attributes inherited from the Vehicle class. It then initializes the year attribute specific to the Car class.

# 13. Create a class called `Book` with a constructor that initializes the `title`, `author`, and `published_year`
# attributes. Provide a method to display book details.
class Book:
   def __init__(self, title, author, published_year):
       self.title = title
       self.author = author
       self.published_year = published_year

   def display_details(self
